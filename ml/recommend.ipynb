# %%
# USER INPUTS (FROM PHASE 4 & 5)
direction = input("Enter price direction (UP / DOWN): ").strip().upper()
confidence = float(input("Enter prediction confidence (in %): "))
sentiment = input("Enter news sentiment (POSITIVE / NEGATIVE / NEUTRAL): ").strip().upper()

print("\nRecommendation Engine")
print("------------------------")

#DECISION LOGIC
if direction == "UP" and confidence >= 55 and sentiment == "POSITIVE":
    recommendation = "BUY 🟢"
elif direction == "DOWN" and confidence >= 55 and sentiment == "NEGATIVE":
    recommendation = "SELL 🔴"
else:
    recommendation = "HOLD 🟡"

# -------- OUTPUT --------
print(f"Price Direction: {direction}")
print(f"Confidence: {confidence:.2f}%")
print(f"News Sentiment: {sentiment}")
print(f"\n Final Recommendation: {recommendation}")
# Out:
# Enter price direction (UP / DOWN):  Down
# Enter prediction confidence (in %):  58.16
# Enter news sentiment (POSITIVE / NEGATIVE / NEUTRAL):  NEUTRAL
# Recommendation Engine
# ------------------------
# Price Direction: DOWN
# Confidence: 58.16%
# News Sentiment: NEUTRAL
#
#  Final Recommendation: HOLD 🟡
